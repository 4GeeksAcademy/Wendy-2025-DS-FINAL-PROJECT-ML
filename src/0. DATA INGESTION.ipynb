# %% [markdown]
# # 0. Data ingestion

# %%
import pandas as pd

# %% [markdown]
# Data set instroduction:
#
# This dataset was compiled in two stages. First, data on housing prices in the Spanish market was collected using sophisticated web scraping techniques. Next, factors related to these prices were sought in official sources such as the INE (National Institute of Statistics). Specific details are provided below.

# %%
df_original = pd.read_csv("./original_data.csv")
df_original.head()
# Out:
#    codigo_comunidad  comunidad       name        year  precio     IPC  \
# 0                 1  andalucia  Andalucía  2003-01-01   995.0  72.838
# 1                 1  andalucia  Andalucía  2003-04-01  1033.0  74.225
# 2                 1  andalucia  Andalucía  2003-07-01  1094.0  73.579
# 3                 1  andalucia  Andalucía  2003-10-01  1133.0  74.736
# 4                 1  andalucia  Andalucía  2004-01-01  1186.0  74.391
#
#    edad_media  mano_obra  precio_Acero  precio_Aluminio  precio_Cemento  \
# 0   37.951542     313.00         719.9            725.8          1349.9
# 1   37.951542     317.54         730.7            728.3          1343.7
# 2   38.049990     315.92         724.4            704.8          1324.6
# 3   38.049990     319.96         717.4            705.4          1331.2
# 4   38.146028     319.41         735.7            711.7          1342.7
#
#    precio_Ceramica  precio_Cobre  precio_Energía  precio_Ligantes  \
# ...
